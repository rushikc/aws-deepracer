# %%
import deepracer

# %%
import pandas as pd

# %%
import math
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from deepracer.tracks import TrackIO, Track

# %%
from deepracer.tracks.track_utils import track_breakdown

# %%
from deepracer.logs import SimulationLogsIO as sio, NewRewardUtils as nr, AnalysisUtils as au, PlottingUtils as pu, ActionBreakdownUtils as abu

# %%
import warnings
warnings.filterwarnings('ignore')

tu =TrackIO()
tu

# %%
track: Track = tu.load_track("2022_may_open")
track

cway = track.center_line
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17080/2881521720.py in <module>
# ----> 1 track: Track = tu.load_track("2022_may_open","counterclockwise")
#       2 track
#       3
#       4 cway = track.center_line
#
# TypeError: load_track() takes 2 positional arguments but 3 were given

# %%
pu.plot_trackpoints(track)
# Out:
# <AxesSubplot:>

# %%
track

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17080/2512202442.py in <module>
# ----> 1 track.clockwise
#
# AttributeError: 'Track' object has no attribute 'clockwise'

# %%
tu.load_track("2022_may_open")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17080/3045199192.py in <module>
# ----> 1 tu.load_track("2022_may_open",'y')
#
# TypeError: load_track() takes 2 positional arguments but 3 were given
